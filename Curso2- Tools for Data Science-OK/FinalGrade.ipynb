# %% [markdown]
# # Jupyter Notebook on IBM Data Science

# %% [markdown]
# **Fabio Ferri**
# I am Sap Architect Solution and AI Data Science Studenty!

# %% [markdown]
# *I am interested in data science to apply in my Area*

# %% [markdown]
# ### My code is supposed to run the Calculator

# %%
lista = [1, 2, 3, 4, 5]
for l in lista:
    print(l+1)
# Out:
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# <a href="www.cnn.com">Cnn International</a>

# %%
s1 = ['a', 'b', 'c', 'd']
for i in s1:
    print(s1.index(i) +1, end=' ')
    print(" ",i)
# Out:
# 1   a
# 2   b
# 3   c
# 4   d

# %%
print('─' * 1000)  # Horizontal Lines
# Out:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...
